# %% [markdown]
# # Base de données de la production agricole en Afrique de l'ouest issu de faostat

# %%
import pandas as pd

# %%
df = pd.read_csv('FAOSTAT_data_fr_7-28-2025 - Copie.csv', sep =';')
df
# Out:
#      Code Domaine            Domaine            Nom_Pays    Nom_Indicateur     \
# 0         QCL      Cultures et produits animaux   Bénin   Superficie récoltée
# 1         QCL      Cultures et produits animaux   Bénin             Rendement
# 2         QCL      Cultures et produits animaux   Bénin            Production
# 3         QCL      Cultures et produits animaux   Bénin   Superficie récoltée
# 4         QCL      Cultures et produits animaux   Bénin             Rendement
# ...           ...                           ...      ...                  ...
# 4815      QCL      Cultures et produits animaux    Togo             Rendement
# 4816      QCL      Cultures et produits animaux    Togo            Production
# 4817      QCL      Cultures et produits animaux    Togo   Superficie récoltée
# 4818      QCL      Cultures et produits animaux    Togo             Rendement
# 4819      QCL      Cultures et produits animaux    Togo            Production
#
# ...

# %%
df.columns
# Out:
# Index(['Code Domaine', 'Domaine', 'Nom_Pays', 'Nom_Indicateur', 'Nom_Produit',
#        'Année', 'Unité_Indicateur', 'Valeur', 'Symbole',
#        'Description du Symbole', 'IDAnnée', 'IDProduit', 'IDPays',
#        'IDIndicateurs'],
#       dtype='object')

# %% [markdown]
# ## Mise en place de l'analyse exploratoire de cette base

# %%
from autoviz.AutoViz_Class import AutoViz_Class

# %%
# Initialisation d'AutoViz
AV = AutoViz_Class()

# Activer l'affichage inline des graphiques
# %matplotlib inline

# Lancer l'analyse automatique de la Base
dfte = AV.AutoViz('FAOSTAT_data_fr_7-28-2025 - Copie.csv', sep=';', depVar='', dfte=None, header=0, verbose=1, lowess=False,
chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)
# Out:
# Shape of your Data Set loaded: (4820, 14)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  1
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  6
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  1
#     Number of ID Columns =  4
#     Number of Columns to Delete =  2
#     14 Predictors classified...
#         6 variable(s) removed since they were ID or low-information variables
# ...

# %%
df.isna().mean()
# Out:
# Code Domaine              0.000000
# Domaine                   0.000000
# Nom_Pays                  0.000000
# Nom_Indicateur            0.000000
# Nom_Produit               0.000000
# Année                     0.000000
# Unité_Indicateur          0.000000
# Valeur                    0.014523
# Symbole                   0.000000
# Description du Symbole    0.000000
# IDAnnée                   0.000000
# IDProduit                 0.000000
# IDPays                    0.000000
# IDIndicateurs             0.000000
# dtype: float64
